# %%
#original Shubham Bhaiya Code

# !pip install bayesian-optimization
# !pip install smote_variants
import numpy as np
import pandas as pd
from sklearn.linear_model import Ridge
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, roc_curve, auc
from bayes_opt import BayesianOptimization
import smote_variants as sv
#Load data
train_data = pd.read_csv('Desktop/Proj Work/TEST/FilteredTrain.csv')
test_data = pd.read_csv('Desktop/Proj Work/TEST/FilteredTest.csv')

#Preprocess data
X_train = train_data.drop(['ID','SMILE ID', 'LABEL'], axis=1).values
X_test = test_data.drop(['ID', 'SMILE ID','LABEL'], axis=1).values

#Label encoding
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(train_data['LABEL'].values)
y_test = label_encoder.transform(test_data['LABEL'].values)

oversampler= sv.AHC()
X_train, y_train= oversampler.sample(X_train, y_train)

#Define activation function and vectorize it
def s_faf(x, j=0.25, k=0.75, m=0.5):
    if x <= j:
        return 0
    elif j < x <= m:
        return 2 * ((x - j) / (k - j)) ** 2
    elif m < x < k:
        return 1 - 2 * ((x - k) / (k - j)) ** 2
    else:
        return 1
vectorized_s_faf = np.vectorize(s_faf)

def model_performance(enhancement_nodes, alpha):
    enhancement_nodes = int(enhancement_nodes)
    input_size = X_train.shape[1]
    random_weights = np.random.uniform(-1, 1, (input_size, enhancement_nodes))
    biases = np.random.uniform(-1, 1, enhancement_nodes)

    def compute_hidden_layer(X):
        G = np.dot(X, random_weights) + biases
        return vectorized_s_faf(G)

    H_train = compute_hidden_layer(X_train)
    H_test = compute_hidden_layer(X_test)

    ridge_model = Ridge(alpha=alpha)
    ridge_model.fit(H_train, y_train)

    raw_scores_train = np.dot(H_train, ridge_model.coef_)
    raw_scores_test = np.dot(H_test, ridge_model.coef_)

    fpr, tpr, thresholds = roc_curve(y_test, raw_scores_test)
    optimal_idx = np.argmax(tpr - fpr)
    optimal_threshold = thresholds[optimal_idx]

    y_pred_train = (raw_scores_train > optimal_threshold) * 1
    y_pred_test = (raw_scores_test > optimal_threshold) * 1

    train_accuracy = accuracy_score(y_train, y_pred_train)
    test_accuracy = accuracy_score(y_test, y_pred_test)

    print(f"Current Iteration: Training Accuracy: {train_accuracy}, Test Accuracy: {test_accuracy}")
    
    return test_accuracy  
#Setup Bayesian optimization
optimizer = BayesianOptimization(
    f=model_performance,
    pbounds={'enhancement_nodes': (10000, 20000), 'alpha': (10,300)},
    random_state=1,
    verbose=2 
)

optimizer.maximize(init_points=30, n_iter=50)

print("Best performance achieved:", optimizer.max['target'])
print("Optimal parameters found:", optimizer.max['params'])
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: bayesian-optimization in c:\users\lenovo\appdata\roaming\python\python311\site-packages (1.4.1)
# Requirement already satisfied: numpy>=1.9.0 in e:\anaconda\lib\site-packages (from bayesian-optimization) (1.26.4)
# Requirement already satisfied: scipy>=1.0.0 in e:\anaconda\lib\site-packages (from bayesian-optimization) (1.11.4)
# Requirement already satisfied: scikit-learn>=0.18.0 in e:\anaconda\lib\site-packages (from bayesian-optimization) (1.2.2)
# Requirement already satisfied: colorama in c:\users\lenovo\appdata\roaming\python\python311\site-packages (from bayesian-optimization) (0.4.6)
# Requirement already satisfied: joblib>=1.1.1 in e:\anaconda\lib\site-packages (from scikit-learn>=0.18.0->bayesian-optimization) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in e:\anaconda\lib\site-packages (from scikit-learn>=0.18.0->bayesian-optimization) (2.2.0)
# 2024-07-01 17:39:10,133:INFO:AHC: Running sampling via ('AHC', "{'strategy': 'min', 'n_jobs': 1, 'random_state': None, 'class_name': 'AHC'}")
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: smote_variants in c:\users\lenovo\appdata\roaming\python\python311\site-packages (0.7.3)
# Requirement already satisfied: numpy in e:\anaconda\lib\site-packages (from smote_variants) (1.26.4)
# Requirement already satisfied: scipy in e:\anaconda\lib\site-packages (from smote_variants) (1.11.4)
# Requirement already satisfied: scikit-learn in e:\anaconda\lib\site-packages (from smote_variants) (1.2.2)
# Requirement already satisfied: joblib in e:\anaconda\lib\site-packages (from smote_variants) (1.2.0)
# Requirement already satisfied: minisom in c:\users\lenovo\appdata\roaming\python\python311\site-packages (from smote_variants) (2.3.2)
# Requirement already satisfied: statistics in c:\users\lenovo\appdata\roaming\python\python311\site-packages (from smote_variants) (1.0.3.5)
# Requirement already satisfied: tensorflow in c:\users\lenovo\appdata\roaming\python\python311\site-packages (from smote_variants) (2.16.2)
# Requirement already satisfied: keras in c:\users\lenovo\appdata\roaming\python\python311\site-packages (from smote_variants) (3.4.1)
# Requirement already satisfied: pandas in e:\anaconda\lib\site-packages (from smote_variants) (2.1.4)
# Requirement already satisfied: mkl in c:\users\lenovo\appdata\roaming\python\python311\site-packages (from smote_variants) (2024.2.0)
# Requirement already satisfied: metric-learn in c:\users\lenovo\appdata\roaming\python\python311\site-packages (from smote_variants) (0.7.0)
# Requirement already satisfied: seaborn in e:\anaconda\lib\site-packages (from smote_variants) (0.12.2)
# Requirement already satisfied: absl-py in c:\users\lenovo\appdata\roaming\python\python311\site-packages (from keras->smote_variants) (2.1.0)
# Requirement already satisfied: rich in e:\anaconda\lib\site-packages (from keras->smote_variants) (13.3.5)
# Requirement already satisfied: namex in c:\users\lenovo\appdata\roaming\python\python311\site-packages (from keras->smote_variants) (0.0.8)
# Requirement already satisfied: h5py in c:\users\lenovo\appdata\roaming\python\python311\site-packages (from keras->smote_variants) (3.11.0)
# Requirement already satisfied: optree in c:\users\lenovo\appdata\roaming\python\python311\site-packages (from keras->smote_variants) (0.11.0)
# Requirement already satisfied: ml-dtypes in c:\users\lenovo\appdata\roaming\python\python311\site-packages (from keras->smote_variants) (0.3.2)
# Requirement already satisfied: packaging in c:\users\lenovo\appdata\roaming\python\python311\site-packages (from keras->smote_variants) (24.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in e:\anaconda\lib\site-packages (from scikit-learn->smote_variants) (2.2.0)
# Requirement already satisfied: intel-openmp>=2023 in c:\users\lenovo\appdata\roaming\python\python311\site-packages (from mkl->smote_variants) (2024.2.0)
# Requirement already satisfied: tbb==2021.* in c:\users\lenovo\appdata\roaming\python\python311\site-packages (from mkl->smote_variants) (2021.13.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\anaconda\lib\site-packages (from pandas->smote_variants) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in e:\anaconda\lib\site-packages (from pandas->smote_variants) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in e:\anaconda\lib\site-packages (from pandas->smote_variants) (2023.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in e:\anaconda\lib\site-packages (from seaborn->smote_variants) (3.8.0)
# Requirement already satisfied: docutils>=0.3 in e:\anaconda\lib\site-packages (from statistics->smote_variants) (0.18.1)
# Requirement already satisfied: tensorflow-intel==2.16.2 in c:\users\lenovo\appdata\roaming\python\python311\site-packages (from tensorflow->smote_variants) (2.16.2)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\lenovo\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.2->tensorflow->smote_variants) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\lenovo\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.2->tensorflow->smote_variants) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\lenovo\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.2->tensorflow->smote_variants) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\lenovo\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.2->tensorflow->smote_variants) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\lenovo\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.2->tensorflow->smote_variants) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\lenovo\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.2->tensorflow->smote_variants) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in e:\anaconda\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow->smote_variants) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in e:\anaconda\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow->smote_variants) (2.31.0)
# Requirement already satisfied: setuptools in e:\anaconda\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow->smote_variants) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in e:\anaconda\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow->smote_variants) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\lenovo\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.2->tensorflow->smote_variants) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\lenovo\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.2->tensorflow->smote_variants) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in e:\anaconda\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow->smote_variants) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\lenovo\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.2->tensorflow->smote_variants) (1.64.1)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in c:\users\lenovo\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.2->tensorflow->smote_variants) (2.16.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\lenovo\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.2->tensorflow->smote_variants) (0.31.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in c:\users\lenovo\appdata\roaming\python\python311\site-packages (from intel-openmp>=2023->mkl->smote_variants) (2024.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in e:\anaconda\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn->smote_variants) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in e:\anaconda\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn->smote_variants) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in e:\anaconda\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn->smote_variants) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in e:\anaconda\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn->smote_variants) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in e:\anaconda\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn->smote_variants) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in e:\anaconda\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn->smote_variants) (3.0.9)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in e:\anaconda\lib\site-packages (from rich->keras->smote_variants) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\lenovo\appdata\roaming\python\python311\site-packages (from rich->keras->smote_variants) (2.18.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in e:\anaconda\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.16.2->tensorflow->smote_variants) (0.41.2)
# Requirement already satisfied: mdurl~=0.1 in e:\anaconda\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras->smote_variants) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in e:\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.2->tensorflow->smote_variants) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in e:\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.2->tensorflow->smote_variants) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.2->tensorflow->smote_variants) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in e:\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.2->tensorflow->smote_variants) (2024.2.2)
# Requirement already satisfied: markdown>=2.6.8 in e:\anaconda\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.2->tensorflow->smote_variants) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\lenovo\appdata\roaming\python\python311\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.2->tensorflow->smote_variants) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in e:\anaconda\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.2->tensorflow->smote_variants) (2.2.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in e:\anaconda\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.2->tensorflow->smote_variants) (2.1.3)
# |   iter    |  target   |   alpha   | enhanc... |
# -------------------------------------------------
# Current Iteration: Training Accuracy: 0.9957196361690743, Test Accuracy: 0.7548076923076923
# | 1         | 0.7548    | 130.9     | 1.72e+04  |
# Current Iteration: Training Accuracy: 0.9962546816479401, Test Accuracy: 0.7644230769230769
# | 2         | 0.7644    | 10.03     | 1.302e+04 |
# Current Iteration: Training Accuracy: 0.9919743178170144, Test Accuracy: 0.7548076923076923
# | 3         | 0.7548    | 52.56     | 1.092e+04 |
# Current Iteration: Training Accuracy: 0.9876939539860888, Test Accuracy: 0.7692307692307693
# | 4         | 0.7692    | 64.02     | 1.346e+04 |
# Current Iteration: Training Accuracy: 0.9962546816479401, Test Accuracy: 0.7548076923076923
# | 5         | 0.7548    | 125.1     | 1.539e+04 |
# Current Iteration: Training Accuracy: 0.990904226859283, Test Accuracy: 0.7548076923076923
# | 6         | 0.7548    | 131.6     | 1.685e+04 |
# Current Iteration: Training Accuracy: 0.9967897271268058, Test Accuracy: 0.7596153846153846
# | 7         | 0.7596    | 69.29     | 1.878e+04 |
# Current Iteration: Training Accuracy: 0.9914392723381488, Test Accuracy: 0.75
# | 8         | 0.75      | 17.94     | 1.67e+04  |
# Current Iteration: Training Accuracy: 0.994649545211343, Test Accuracy: 0.7403846153846154
# | 9         | 0.7404    | 131.0     | 1.559e+04 |
# Current Iteration: Training Accuracy: 0.990904226859283, Test Accuracy: 0.75
# | 10        | 0.75      | 50.71     | 1.198e+04 |
# Current Iteration: Training Accuracy: 0.9818084537185661, Test Accuracy: 0.7644230769230769
# | 11        | 0.7644    | 242.2     | 1.968e+04 |
# Current Iteration: Training Accuracy: 0.9962546816479401, Test Accuracy: 0.7548076923076923
# | 12        | 0.7548    | 100.9     | 1.692e+04 |
# Current Iteration: Training Accuracy: 0.9892990904226859, Test Accuracy: 0.7403846153846154
# | 13        | 0.7404    | 264.2     | 1.895e+04 |
# Current Iteration: Training Accuracy: 0.9941144997324772, Test Accuracy: 0.7259615384615384
# | 14        | 0.726     | 34.66     | 1.039e+04 |
# Current Iteration: Training Accuracy: 0.9919743178170144, Test Accuracy: 0.7884615384615384
# | 15        | 0.7885    | 59.25     | 1.878e+04 |
# Current Iteration: Training Accuracy: 0.9967897271268058, Test Accuracy: 0.7548076923076923
# | 16        | 0.7548    | 38.52     | 1.421e+04 |
# Current Iteration: Training Accuracy: 0.9930444087747459, Test Accuracy: 0.7403846153846154
# | 17        | 0.7404    | 287.8     | 1.533e+04 |
# Current Iteration: Training Accuracy: 0.9844836811128946, Test Accuracy: 0.7355769230769231
# | 18        | 0.7356    | 210.6     | 1.316e+04 |
# Current Iteration: Training Accuracy: 0.9839486356340289, Test Accuracy: 0.7596153846153846
# | 19        | 0.7596    | 209.1     | 1.835e+04 |
# Current Iteration: Training Accuracy: 0.9967897271268058, Test Accuracy: 0.7596153846153846
# | 20        | 0.7596    | 15.3      | 1.75e+04  |
# Current Iteration: Training Accuracy: 0.9871589085072231, Test Accuracy: 0.7692307692307693
# | 21        | 0.7692    | 296.8     | 1.748e+04 |
# Current Iteration: Training Accuracy: 0.9914392723381488, Test Accuracy: 0.7451923076923077
# | 22        | 0.7452    | 91.33     | 1.789e+04 |
# Current Iteration: Training Accuracy: 0.990904226859283, Test Accuracy: 0.75
# | 23        | 0.75      | 39.94     | 1.448e+04 |
# Current Iteration: Training Accuracy: 0.985553772070626, Test Accuracy: 0.7596153846153846
# | 24        | 0.7596    | 273.5     | 1.294e+04 |
# Current Iteration: Training Accuracy: 0.990904226859283, Test Accuracy: 0.7884615384615384
# | 25        | 0.7885    | 93.45     | 1.13e+04  |
# Current Iteration: Training Accuracy: 0.9930444087747459, Test Accuracy: 0.7403846153846154
# | 26        | 0.7404    | 15.62     | 1.679e+04 |
# Current Iteration: Training Accuracy: 0.9914392723381488, Test Accuracy: 0.7884615384615384
# | 27        | 0.7885    | 71.37     | 1.266e+04 |
# Current Iteration: Training Accuracy: 0.9962546816479401, Test Accuracy: 0.7259615384615384
# | 71        | 0.726     | 109.6     | 1.639e+04 |
# Current Iteration: Training Accuracy: 0.9887640449438202, Test Accuracy: 0.7548076923076923
# | 72        | 0.7548    | 220.9     | 1.241e+04 |
# Current Iteration: Training Accuracy: 0.9903691813804173, Test Accuracy: 0.7451923076923077
# | 73        | 0.7452    | 227.9     | 1.859e+04 |
# Current Iteration: Training Accuracy: 0.9882289994649546, Test Accuracy: 0.7596153846153846
# | 74        | 0.7596    | 56.01     | 1.67e+04  |
# Current Iteration: Training Accuracy: 0.9914392723381488, Test Accuracy: 0.75
# | 75        | 0.75      | 94.85     | 1.998e+04 |
# Current Iteration: Training Accuracy: 0.9850187265917603, Test Accuracy: 0.7596153846153846
# | 76        | 0.7596    | 287.9     | 1.4e+04   |
# Current Iteration: Training Accuracy: 0.9973247726056714, Test Accuracy: 0.7355769230769231
# | 77        | 0.7356    | 48.07     | 1.864e+04 |
# Current Iteration: Training Accuracy: 0.9571963616907437, Test Accuracy: 0.7355769230769231
# | 78        | 0.7356    | 209.8     | 1.016e+04 |
# Current Iteration: Training Accuracy: 0.9871589085072231, Test Accuracy: 0.7644230769230769
# | 79        | 0.7644    | 205.5     | 1.964e+04 |
# Current Iteration: Training Accuracy: 0.9930444087747459, Test Accuracy: 0.7596153846153846
# | 80        | 0.7596    | 66.26     | 1.186e+04 |
# =================================================
# Best performance achieved: 0.7884615384615384
# Optimal parameters found: {'alpha': 59.25082167372498, 'enhancement_nodes': 18781.42503429413}

# %%
 # Original Shubham Bhaiya wala code

 import numpy as np
 import pandas as pd
 from sklearn.linear_model import Ridge
 from sklearn.preprocessing import LabelEncoder
 from sklearn.metrics import accuracy_score, roc_curve, auc

 # Load data
 train_data = pd.read_csv('Desktop/Proj Work/TEST/FilteredTrain.csv')
 test_data = pd.read_csv('Desktop/Proj Work/TEST/FilteredTest.csv')

 # Preprocess data
 X_train = train_data.drop(['ID', 'SMILE ID', 'LABEL'], axis=1).values
 X_test = test_data.drop(['ID', 'SMILE ID', 'LABEL'], axis=1).values

 # Label encoding
 label_encoder = LabelEncoder()
 y_train = label_encoder.fit_transform(train_data['LABEL'].values)
 y_test = label_encoder.transform(test_data['LABEL'].values)


 # Define activation function and vectorize it
 def s_faf(x, j=0.25, k=0.75, m=0.5):
     if x <= j:
         return 0
     elif j < x <= m:
         return 2 * ((x - j) / (k - j)) ** 2
     elif m < x < k:
         return 1 - 2 * ((x - k) / (k - j)) ** 2
     else:
         return 1
 vectorized_s_faf = np.vectorize(s_faf)

 # RVFL network setup
 enhancement_nodes = 18781
 input_size = X_train.shape[1]
 random_weights = np.random.uniform(-1, 1, (input_size, enhancement_nodes))
 biases = np.random.uniform(-1, 1, enhancement_nodes)

 def compute_hidden_layer(X):
     G = np.dot(X, random_weights) + biases
     return vectorized_s_faf(G)

 H_train = compute_hidden_layer(X_train)
 H_test = compute_hidden_layer(X_test)

 # Solve the linear system for output weights
 ridge_model = Ridge(alpha=59)
 ridge_model.fit(H_train, y_train)
 output_weights = ridge_model.coef_

 # Compute raw scores for ROC analysis
 raw_scores_train = np.dot(H_train, output_weights)
 raw_scores_test = np.dot(H_test, output_weights)

 # Compute ROC curve and AUC
 fpr, tpr, thresholds = roc_curve(y_test, raw_scores_test)
 roc_auc = auc(fpr, tpr)

 # Determine the optimal threshold
 optimal_idx = np.argmax(tpr - fpr)
 optimal_threshold = thresholds[optimal_idx]

 # Predictions using the optimal threshold
 y_pred_train = (raw_scores_train > optimal_threshold) * 1
 y_pred_test = (raw_scores_test > optimal_threshold) * 1

 # Evaluate model
 train_accuracy = accuracy_score(y_train, y_pred_train)
 test_accuracy = accuracy_score(y_test, y_pred_test)

 print("Training Accuracy:", train_accuracy)
 print("Testing Accuracy:", test_accuracy)
 print("Optimal Threshold:", optimal_threshold)
 print("AUC:", roc_auc)
# Out:
# Training Accuracy: 0.99122106943336
# Testing Accuracy: 0.7644230769230769
# Optimal Threshold: 0.5236027269442505
# AUC: 0.792973124300112

# %%
#RVFL+


# !pip install optuna
import numpy as np
from sklearn.base import BaseEstimator, RegressorMixin, ClassifierMixin
from sklearn.linear_model import Ridge
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, mean_squared_error
from sklearn.preprocessing import LabelEncoder
import optuna
import pandas as pd

train_data = pd.read_csv('Desktop/Proj Work/TEST/FilteredTrain.csv')
test_data = pd.read_csv('Desktop/Proj Work/TEST/FilteredTest.csv')

# Preprocess data
X_train = train_data.drop(['ID', 'SMILE ID', 'LABEL'], axis=1).values
X_test = test_data.drop(['ID', 'SMILE ID', 'LABEL'], axis=1).values

# Label encoding
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(train_data['LABEL'].values)
y_test = label_encoder.transform(test_data['LABEL'].values)

class RVFL(BaseEstimator, RegressorMixin, ClassifierMixin):
    def __init__(self, n_hidden=20, alpha=0.1, random_state=None):
        self.n_hidden = n_hidden
        self.alpha = alpha
        self.random_state = random_state

    def _init_weights(self, n_features):
        rng = np.random.default_rng(self.random_state)
        self.W = rng.uniform(-1, 1, size=(n_features, self.n_hidden))
        self.b = rng.uniform(-1, 1, size=self.n_hidden)

    def fit(self, X, y):
        self.scaler = StandardScaler()
        X = self.scaler.fit_transform(X)
        n_samples, n_features = X.shape
        self._init_weights(n_features)
        
        Z = np.tanh(X @ self.W + self.b)
        Z = np.hstack((X, Z))  # Augment with original features
        self.ridge = Ridge(alpha=self.alpha)
        self.ridge.fit(Z, y)
        return self

    def predict(self, X):
        X = self.scaler.transform(X)
        Z = np.tanh(X @ self.W + self.b)
        Z = np.hstack((X, Z))  # Augment with original features
        return self.ridge.predict(Z)
    
    def score(self, X, y):
        y_pred = self.predict(X)
        if len(np.unique(y)) > 2:
            return mean_squared_error(y, y_pred)
        else:
            return accuracy_score(y, np.round(y_pred))

# Define objective function for Optuna
def objective(trial):
    n_hidden = trial.suggest_int('n_hidden', 15000, 20000)
    alpha = trial.suggest_float('alpha', 1e-3, 1e3, log=True)
    random_state = trial.suggest_int('random_state', 1, 100)

    model = RVFL(n_hidden=n_hidden, alpha=alpha, random_state=random_state)
    model.fit(X_train, y_train)
    return model.score(X_test, y_test)

# Run Bayesian optimization
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=250, timeout=2000)

print("Best parameters:", study.best_params)
print("Best score:", study.best_value)

# Train final model with best parameters
best_params = study.best_params
final_model = RVFL(**best_params)
final_model.fit(X_train, y_train)

# Predict and evaluate on the test dataset
y_pred = final_model.predict(X_test)
accuracy = accuracy_score(y_test, np.round(y_pred))
print("Final model accuracy on test set:", accuracy)
# Out:
# [I 2024-07-01 20:49:10,357] A new study created in memory with name: no-name-1dd89a43-94a1-4e2f-a5e8-711c0ab7507a
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: optuna in c:\users\lenovo\appdata\roaming\python\python311\site-packages (3.6.1)
# Requirement already satisfied: alembic>=1.5.0 in c:\users\lenovo\appdata\roaming\python\python311\site-packages (from optuna) (1.13.2)
# Requirement already satisfied: colorlog in c:\users\lenovo\appdata\roaming\python\python311\site-packages (from optuna) (6.8.2)
# Requirement already satisfied: numpy in e:\anaconda\lib\site-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\lenovo\appdata\roaming\python\python311\site-packages (from optuna) (24.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in e:\anaconda\lib\site-packages (from optuna) (2.0.25)
# Requirement already satisfied: tqdm in e:\anaconda\lib\site-packages (from optuna) (4.65.0)
# Requirement already satisfied: PyYAML in e:\anaconda\lib\site-packages (from optuna) (6.0.1)
# Requirement already satisfied: Mako in c:\users\lenovo\appdata\roaming\python\python311\site-packages (from alembic>=1.5.0->optuna) (1.3.5)
# Requirement already satisfied: typing-extensions>=4 in c:\users\lenovo\appdata\roaming\python\python311\site-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in e:\anaconda\lib\site-packages (from sqlalchemy>=1.3.0->optuna) (3.0.1)
# Requirement already satisfied: colorama in c:\users\lenovo\appdata\roaming\python\python311\site-packages (from colorlog->optuna) (0.4.6)
# Requirement already satisfied: MarkupSafe>=0.9.2 in e:\anaconda\lib\site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.3)
# [I 2024-07-01 20:49:12,421] Trial 0 finished with value: 0.7740384615384616 and parameters: {'n_hidden': 16713, 'alpha': 36.576230770791376, 'random_state': 71}. Best is trial 0 with value: 0.7740384615384616.
# [I 2024-07-01 20:49:14,365] Trial 1 finished with value: 0.7307692307692307 and parameters: {'n_hidden': 17144, 'alpha': 13.252909867038007, 'random_state': 84}. Best is trial 0 with value: 0.7740384615384616.
# [I 2024-07-01 20:49:16,269] Trial 2 finished with value: 0.7644230769230769 and parameters: {'n_hidden': 16353, 'alpha': 1.621672247757004, 'random_state': 5}. Best is trial 0 with value: 0.7740384615384616.
# [I 2024-07-01 20:49:17,931] Trial 3 finished with value: 0.7836538461538461 and parameters: {'n_hidden': 17256, 'alpha': 0.554104899459969, 'random_state': 72}. Best is trial 3 with value: 0.7836538461538461.
# [I 2024-07-01 20:49:19,630] Trial 4 finished with value: 0.7740384615384616 and parameters: {'n_hidden': 18273, 'alpha': 0.0016082100213268944, 'random_state': 72}. Best is trial 3 with value: 0.7836538461538461.
# [I 2024-07-01 20:49:21,415] Trial 5 finished with value: 0.7740384615384616 and parameters: {'n_hidden': 15775, 'alpha': 0.0018344172043815669, 'random_state': 100}. Best is trial 3 with value: 0.7836538461538461.
# [I 2024-07-01 20:49:23,714] Trial 6 finished with value: 0.7788461538461539 and parameters: {'n_hidden': 17835, 'alpha': 0.14833827603142494, 'random_state': 95}. Best is trial 3 with value: 0.7836538461538461.
# [I 2024-07-01 20:49:25,785] Trial 7 finished with value: 0.75 and parameters: {'n_hidden': 17284, 'alpha': 31.30764503722188, 'random_state': 21}. Best is trial 3 with value: 0.7836538461538461.
# [I 2024-07-01 20:49:27,943] Trial 8 finished with value: 0.7644230769230769 and parameters: {'n_hidden': 16619, 'alpha': 0.3319331812373179, 'random_state': 79}. Best is trial 3 with value: 0.7836538461538461.
# [I 2024-07-01 20:49:29,968] Trial 9 finished with value: 0.7355769230769231 and parameters: {'n_hidden': 18653, 'alpha': 0.017102855144515452, 'random_state': 36}. Best is trial 3 with value: 0.7836538461538461.
# [I 2024-07-01 20:49:32,512] Trial 10 finished with value: 0.75 and parameters: {'n_hidden': 19992, 'alpha': 595.9070899502354, 'random_state': 51}. Best is trial 3 with value: 0.7836538461538461.
# [I 2024-07-01 20:49:34,766] Trial 11 finished with value: 0.7980769230769231 and parameters: {'n_hidden': 18195, 'alpha': 0.18098337452777308, 'random_state': 91}. Best is trial 11 with value: 0.7980769230769231.
# [I 2024-07-01 20:49:36,928] Trial 12 finished with value: 0.7740384615384616 and parameters: {'n_hidden': 19115, 'alpha': 0.03638197657478569, 'random_state': 58}. Best is trial 11 with value: 0.7980769230769231.
# [I 2024-07-01 20:49:39,010] Trial 13 finished with value: 0.7836538461538461 and parameters: {'n_hidden': 17849, 'alpha': 2.0924898631632263, 'random_state': 61}. Best is trial 11 with value: 0.7980769230769231.
# [I 2024-07-01 20:49:40,155] Trial 14 finished with value: 0.7836538461538461 and parameters: {'n_hidden':